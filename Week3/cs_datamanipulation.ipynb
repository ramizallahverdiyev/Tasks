# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Question 1

# %%
train = pd.read_csv('train.csv')
train.head(7)
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
# 5  train_5       0  11.4763 -2.3182  12.6080  8.6264  10.9621  3.5609  4.5322
# 6  train_6       0  11.8091 -0.0832   9.3494  4.2916  11.1355 -8.0198  6.1961
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# ...

# %% [markdown]
# Question 2

# %%
train.isnull().any().any()
# Out:
# False

# %%
train.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Question 3

# %%
train['target'].value_counts()
# Out:
# target
# 0    179902
# 1     20098
# Name: count, dtype: int64

# %%
train.groupby('target').mean(numeric_only=True)
# Out:
#             var_0     var_1      var_2     var_3      var_4     var_5  \
# target
# 0       10.626681 -1.695770  10.665876  6.788979  11.072412 -5.146736
# 1       11.156418 -1.017613  11.156633  6.864113  11.131337 -4.336522
#
#            var_6      var_7     var_8     var_9  ...   var_190  var_191  \
# target                                           ...
# 0       5.389620  16.549306  0.262347  7.584907  ...  3.149130  7.39080
# 1       5.581966  16.514917  0.479432  7.409064  ...  3.998064  7.86456
#
#          var_192   var_193    var_194   var_195   var_196   var_197  \
# target
# 0       1.949017  3.355403  18.017716 -0.155601  2.260297  8.919032
# 1       1.738266  3.120260  17.779568 -0.021130  2.688583  8.810815
#
#           var_198   var_199
# target
# 0       15.924058 -3.415273
# 1       15.393283 -2.532243
#
# [2 rows x 200 columns]

# %% [markdown]
# Question 4

# %%
train['target'].value_counts()
# Out:
# target
# 0    179902
# 1     20098
# Name: count, dtype: int64

# %% [markdown]
# Question 5

# %%
train.drop('ID_code', axis=1)
# Out:
#         target    var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 0            0   8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187
# 1            0  11.5006 -4.1473  13.8588  5.3890  12.3622   7.0433  5.6208
# 2            0   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427
# 3            0  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428
# 4            0   9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405
# ...        ...      ...     ...      ...     ...      ...      ...     ...
# 199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404  11.6081  5.6709
# 199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802
# 199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410  -5.4086  4.5555
# 199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173   0.5339  6.0479
# 199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839
#
# ...

# %% [markdown]
# Question 6

# %% [markdown]
# a.

# %%
train.describe().T[['std', 'min', 'max', 'mean']]
# Out:
#                std      min      max       mean
# target    0.300653   0.0000   1.0000   0.100490
# var_0     3.040051   0.4084  20.3150  10.679914
# var_1     4.050044 -15.0434  10.3768  -1.627622
# var_2     2.640894   2.1171  19.3530  10.715192
# var_3     2.043319  -0.0402  13.1883   6.796529
# ...            ...      ...      ...        ...
# var_195   1.429372  -5.2610   4.2729  -0.142088
# var_196   5.454369 -14.2096  18.3215   2.303335
# var_197   0.921625   5.9606  12.0004   8.908158
# var_198   3.010945   6.2993  26.0791  15.870720
# var_199  10.438015 -38.8528  28.5007  -3.326537
#
# [201 rows x 4 columns]

# %% [markdown]
# b.

# %%
train['var_0'].mean()
# Out:
# 10.679914251999998

# %% [markdown]
# Question 7

# %%
var0_mean = train['var_0'].mean()

var0_filtered = train[(train['var_0'] >= train['var_0'].min()) & (train['var_0'] <= var0_mean)]

var0_filtered
# Out:
#              ID_code  target   var_0   var_1    var_2   var_3    var_4  \
# 0            train_0       0  8.9255 -6.7863  11.9081  5.0930  11.4607
# 2            train_2       0  8.6093 -2.7457  12.0805  7.8928  10.5825
# 4            train_4       0  9.8369 -1.4834  12.8746  6.6375  12.2772
# 10          train_10       0  5.0702 -0.5447   9.5900  4.2987  12.3910
# 12          train_12       0  8.7671 -4.6154   9.7242  7.4242   9.0254
# ...              ...     ...     ...     ...      ...     ...      ...
# 199985  train_199985       0  9.0249 -3.6379  12.3907  5.1915  12.1701
# 199987  train_199987       0  8.0438 -1.9184  13.1498  9.2027   8.9886
# 199991  train_199991       0  9.9909  2.5523  11.9653  6.3958  13.5497
# 199996  train_199996       0  4.9149 -2.4484  16.7052  6.6345   8.3096
# 199998  train_199998       0  9.7148 -8.6098  13.6104  5.7930  12.5173
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# ...

# %% [markdown]
# Question 8

# %%
train[(train['var_6']>5)&(train['var_196']<2)]
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 2            train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825
# 3            train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846
# 11          train_11       0  12.7188 -7.9750  10.3757  9.0101  12.8570
# 14          train_14       0  13.8080  5.0514  17.2611  8.5120  12.8517
# 16          train_16       0   5.0615  0.2689  15.1325  3.6587  13.5276
# ...              ...     ...      ...     ...      ...     ...      ...
# 199990  train_199990       1  14.1475  1.8568  11.0066  3.6779  12.1944
# 199991  train_199991       0   9.9909  2.5523  11.9653  6.3958  13.5497
# 199994  train_199994       0  12.3925 -5.8821  11.2323  3.9237  10.4509
# 199996  train_199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096
# 199999  train_199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# ...

# %% [markdown]
# Question 9

# %%
observations = train.iloc[20000:30001, 10]

observations
# Out:
# 20000    6.4937
# 20001    2.9890
# 20002   -3.5001
# 20003   -6.4872
# 20004    1.6192
#           ...
# 29996    2.1573
# 29997    3.9680
# 29998   -1.5761
# 29999   -3.2388
# 30000   -1.0424
# Name: var_8, Length: 10001, dtype: float64

# %% [markdown]
# Question 10

# %% [markdown]
# a.

# %%
corr_ = train.loc[:, 'var_0' : 'var_9'].corr()
corr_
# Out:
#           var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# var_0  1.000000 -0.000544  0.006573  0.003801  0.001326  0.003046  0.006983
# var_1 -0.000544  1.000000  0.003980  0.000010  0.000303 -0.000902  0.003258
# var_2  0.006573  0.003980  1.000000  0.001001  0.000723  0.001569  0.000883
# var_3  0.003801  0.000010  0.001001  1.000000 -0.000322  0.003253 -0.000774
# var_4  0.001326  0.000303  0.000723 -0.000322  1.000000 -0.001368  0.000049
# var_5  0.003046 -0.000902  0.001569  0.003253 -0.001368  1.000000  0.002588
# var_6  0.006983  0.003258  0.000883 -0.000774  0.000049  0.002588  1.000000
# var_7  0.002429  0.001511 -0.000991  0.002500  0.004549 -0.000995 -0.002548
# var_8  0.004962  0.004098  0.002648  0.003553  0.001194  0.000147 -0.001188
# var_9 -0.002613 -0.000832 -0.001932 -0.000826 -0.000918 -0.005279 -0.005697
#
#           var_7     var_8     var_9
# var_0  0.002429  0.004962 -0.002613
# var_1  0.001511  0.004098 -0.000832
# ...

# %% [markdown]
# b, c

# %%
abs(corr_).replace(1,np.nan)\
.unstack().reset_index().dropna().sort_values(ascending=False, by=0).iloc[:20:2]
# Out:
#    level_0 level_1         0
# 60   var_6   var_0  0.006983
# 2    var_0   var_2  0.006573
# 69   var_6   var_9  0.005697
# 59   var_5   var_9  0.005279
# 8    var_0   var_8  0.004962
# 47   var_4   var_7  0.004549
# 18   var_1   var_8  0.004098
# 12   var_1   var_2  0.003980
# 30   var_3   var_0  0.003801
# 83   var_8   var_3  0.003553

# %% [markdown]
# Question 11

# %%
train = train.iloc[:,1:]

# %%
train
# Out:
#         target    var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 0            0   8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187
# 1            0  11.5006 -4.1473  13.8588  5.3890  12.3622   7.0433  5.6208
# 2            0   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427
# 3            0  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428
# 4            0   9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405
# ...        ...      ...     ...      ...     ...      ...      ...     ...
# 199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404  11.6081  5.6709
# 199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802
# 199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410  -5.4086  4.5555
# 199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173   0.5339  6.0479
# 199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839
#
# ...

# %%
quartile_1 = train.quantile(.25)
quartile_3 = train.quantile(.75)

iqr = quartile_3 - quartile_1

lower_bound = quartile_1 - 1.5 * iqr
upper_bound = quartile_3 + 1.5 * iqr

for col in train.columns:
    train = train[~((train[col] < lower_bound[col]) | (train[col] > upper_bound[col]))]

# %%
train
# Out:
#         target    var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 0            0   8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187
# 2            0   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427
# 3            0  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428
# 4            0   9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405
# 5            0  11.4763 -2.3182  12.6080  8.6264  10.9621   3.5609  4.5322
# ...        ...      ...     ...      ...     ...      ...      ...     ...
# 199993       0  13.2152 -5.8006   9.7260  6.5910  12.4612  -7.1652  6.0666
# 199994       0  12.3925 -5.8821  11.2323  3.9237  10.4509  10.7262  7.0503
# 199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404  11.6081  5.6709
# 199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410  -5.4086  4.5555
# 199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839
#
# ...
